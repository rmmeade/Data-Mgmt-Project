# %%
import pandas as pd

# %%
read_file = pd.read_csv('crash.csv')
# Out:
# C:\Users\rmead\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (20,21,23,35,36,38,47,82,155,156) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.DataFrame(read_file)
df.head()
# Out:
#    Unnamed: 0  Crash_ID Crash_Fatal_Fl Cmv_Involv_Fl Schl_Bus_Fl Rr_Relat_Fl  \
# 0           0  11152580              N             N           N           N
# 1           1  11153849              N             N           N           N
# 2           2  11154056              N             N           N           N
# 3           3  11154058              N             N           N           N
# 4           4  11154059              N             N           N           N
#
#   Medical_Advisory_Fl Amend_Supp_Fl Active_School_Zone_Fl  Crash_Date  ...  \
# 0                   N             N                     N  01/15/2010  ...
# 1                   N             N                     N  01/15/2010  ...
# 2                   N             N                     N  01/13/2010  ...
# 3                   N             N                     N  01/13/2010  ...
# 4                   N             N                     N  01/12/2010  ...
#
# ...

# %%
#df.drop(
print(df.columns[1])#, axis = 1)
# Out:
# Crash_ID
