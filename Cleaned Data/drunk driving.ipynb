# %%
import numpy as np
import pandas as pd

# %%
crash = pd.read_csv('crash_clean.csv')

# %%
crash.head()
# Out:
#    Unnamed: 0  Crash_ID Crash_Fatal_Fl  Crash_Date Crash_Time  \
# 0           0  11152580              N  01/15/2010   12:06 PM
# 1           1  11153849              N  01/15/2010   04:32 PM
# 2           2  11154056              N  01/13/2010   06:38 PM
# 3           3  11154058              N  01/13/2010   03:47 PM
# 4           4  11154059              N  01/12/2010   04:51 PM
#
#    Rpt_Rdwy_Sys_ID Rpt_Hwy_Num Private_Dr_Fl  Crash_Speed_Limit At_Intrsct_Fl  \
# 0               19         NaN             N                 35             N
# 1               19         NaN             N                  0             Y
# 2               19         NaN             N                 35             Y
# 3               19         NaN             N                 30             N
# 4                1          35             N                 55             N
#
#    ...  Obj_Struck_ID   Latitude  Longitude  Street_Name  Street_Nbr  \
# 0  ...             64  30.376001 -97.673639  E BRAKER LN       867.0
# 1  ...             29  30.307715 -97.726472    E 45TH ST       300.0
# 2  ...             64  30.265225 -97.740032     E 4TH ST       398.0
# 3  ...             64  30.300115 -97.732672    E 38TH ST       200.0
# 4  ...             64  30.292341 -97.721250       IH0035         NaN
#
#    Street_Name_2  Crash_Sev_ID Day_of_Week  Tot_Injry_Cnt Death_Cnt
# 0            NaN             3         FRI              2         0
# 1        UNKNOWN             3         FRI              1         0
# 2     TRINITY ST             3         WED              1         0
# 3        UNKNOWN             3         WED              1         0
# 4            NaN             5         TUE              0         0
#
# [5 rows x 24 columns]

# %%
p_person = pd.read_csv('primary_person_clean.csv')

# %%
p_person.head(10)
# Out:
#    Unnamed: 0  Crash_ID  Prsn_Occpnt_Pos_ID  Prsn_Injry_Sev_ID  Prsn_Age  \
# 0           0  11152580                 1.0                3.0      24.0
# 1           1  11152580                 1.0                5.0      60.0
# 2           2  11152580                 1.0                5.0      23.0
# 3           3  11153849                 1.0                5.0       NaN
# 4           4  11153849                 1.0                5.0       NaN
# 5           5  11154056                16.0                3.0      45.0
# 6           6  11154056                 1.0                5.0      22.0
# 7           7  11154058                 1.0                5.0      34.0
# 8           8  11154058                 1.0                3.0      25.0
# 9           9  11154058                 1.0                5.0      49.0
#
#    Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  Prsn_Rest_ID  \
# 0                1.0           2.0           1.0           1.0
# 1                2.0           1.0           1.0           1.0
# 2                2.0           1.0           1.0           1.0
# 3                2.0           1.0           1.0           1.0
# 4                2.0           1.0           1.0           1.0
# 5                1.0           1.0           4.0          11.0
# 6                1.0           1.0           1.0           1.0
# 7                2.0           2.0           1.0           1.0
# 8                1.0           2.0           1.0           1.0
# 9                1.0           2.0           1.0           1.0
#
#    Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Alc_Spec_Type_ID  Prsn_Alc_Rslt_ID  \
# 0             2.0            97.0                    4.0               NaN
# 1             2.0            97.0                    4.0               NaN
# 2             2.0            97.0                    4.0               NaN
# 3             2.0            97.0                    4.0               NaN
# 4             3.0            97.0                    4.0               NaN
# 5             1.0            97.0                    4.0               NaN
# 6             2.0            97.0                    4.0               NaN
# 7             2.0            97.0                    4.0               NaN
# 8             0.0            97.0                    4.0               NaN
# 9             2.0            97.0                    4.0               NaN
#
#    Prsn_Bac_Test_Rslt  Prsn_Drg_Rslt_ID  Drvr_Drg_Cat_1_ID
# 0                 NaN              97.0               97.0
# 1                 NaN              97.0               97.0
# 2                 NaN              97.0               97.0
# 3                 NaN              97.0               97.0
# 4                 NaN              97.0               97.0
# 5                 NaN              97.0               97.0
# 6                 NaN              97.0               97.0
# 7                 NaN              97.0               97.0
# 8                 NaN              97.0               97.0
# 9                 NaN              97.0               97.0

# %%
merged = crash.merge(p_person, left_on='Crash_ID', right_on='Crash_ID')

# %%
merged.head(10)
# Out:
#    Unnamed: 0_x  Crash_ID Crash_Fatal_Fl  Crash_Date Crash_Time  \
# 0             0  11152580              N  01/15/2010   12:06 PM
# 1             0  11152580              N  01/15/2010   12:06 PM
# 2             0  11152580              N  01/15/2010   12:06 PM
# 3             1  11153849              N  01/15/2010   04:32 PM
# 4             1  11153849              N  01/15/2010   04:32 PM
# 5             2  11154056              N  01/13/2010   06:38 PM
# 6             2  11154056              N  01/13/2010   06:38 PM
# 7             3  11154058              N  01/13/2010   03:47 PM
# 8             3  11154058              N  01/13/2010   03:47 PM
# 9             3  11154058              N  01/13/2010   03:47 PM
#
#    Rpt_Rdwy_Sys_ID Rpt_Hwy_Num Private_Dr_Fl  Crash_Speed_Limit At_Intrsct_Fl  \
# 0               19         NaN             N                 35             N
# 1               19         NaN             N                 35             N
# 2               19         NaN             N                 35             N
# 3               19         NaN             N                  0             Y
# 4               19         NaN             N                  0             Y
# 5               19         NaN             N                 35             Y
# 6               19         NaN             N                 35             Y
# 7               19         NaN             N                 30             N
# 8               19         NaN             N                 30             N
# 9               19         NaN             N                 30             N
#
#    ...  Prsn_Gndr_ID  Prsn_Ejct_ID  Prsn_Rest_ID Prsn_Airbag_ID  \
# 0  ...           2.0           1.0           1.0            2.0
# 1  ...           1.0           1.0           1.0            2.0
# 2  ...           1.0           1.0           1.0            2.0
# 3  ...           1.0           1.0           1.0            2.0
# 4  ...           1.0           1.0           1.0            3.0
# 5  ...           1.0           4.0          11.0            1.0
# 6  ...           1.0           1.0           1.0            2.0
# 7  ...           2.0           1.0           1.0            2.0
# 8  ...           2.0           1.0           1.0            0.0
# 9  ...           2.0           1.0           1.0            2.0
#
#    Prsn_Helmet_ID  Prsn_Alc_Spec_Type_ID  Prsn_Alc_Rslt_ID Prsn_Bac_Test_Rslt  \
# 0            97.0                    4.0               NaN                NaN
# 1            97.0                    4.0               NaN                NaN
# 2            97.0                    4.0               NaN                NaN
# 3            97.0                    4.0               NaN                NaN
# 4            97.0                    4.0               NaN                NaN
# 5            97.0                    4.0               NaN                NaN
# 6            97.0                    4.0               NaN                NaN
# 7            97.0                    4.0               NaN                NaN
# 8            97.0                    4.0               NaN                NaN
# 9            97.0                    4.0               NaN                NaN
#
#    Prsn_Drg_Rslt_ID Drvr_Drg_Cat_1_ID
# 0              97.0              97.0
# 1              97.0              97.0
# 2              97.0              97.0
# 3              97.0              97.0
# 4              97.0              97.0
# 5              97.0              97.0
# 6              97.0              97.0
# 7              97.0              97.0
# 8              97.0              97.0
# 9              97.0              97.0
#
# [10 rows x 39 columns]

# %%
merged.to_csv('drunk_driving.csv')

# %%
merged.columns
# Out:
# Index(['Unnamed: 0_x', 'Crash_ID', 'Crash_Fatal_Fl', 'Crash_Date',
#        'Crash_Time', 'Rpt_Rdwy_Sys_ID', 'Rpt_Hwy_Num', 'Private_Dr_Fl',
#        'Crash_Speed_Limit', 'At_Intrsct_Fl', 'Wthr_Cond_ID', 'Light_Cond_ID',
#        'Traffic_Cntl_ID', 'Investigat_Notify_Time', 'Obj_Struck_ID',
#        'Latitude', 'Longitude', 'Street_Name', 'Street_Nbr', 'Street_Name_2',
#        'Crash_Sev_ID', 'Day_of_Week', 'Tot_Injry_Cnt', 'Death_Cnt',
#        'Unnamed: 0_y', 'Prsn_Occpnt_Pos_ID', 'Prsn_Injry_Sev_ID', 'Prsn_Age',
#        'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID', 'Prsn_Ejct_ID', 'Prsn_Rest_ID',
#        'Prsn_Airbag_ID', 'Prsn_Helmet_ID', 'Prsn_Alc_Spec_Type_ID',
#        'Prsn_Alc_Rslt_ID', 'Prsn_Bac_Test_Rslt', 'Prsn_Drg_Rslt_ID',
#        'Drvr_Drg_Cat_1_ID'],
#       dtype='object')

# %%
sum(df['Prsn_Alc_Rslt_ID'].notna())
# Out:
# 4679

# %%
sum(df['Prsn_Alc_Rslt_ID'].notna())/len(df['Prsn_Alc_Rslt_ID'])
# Out:
# 0.016332728288187656
